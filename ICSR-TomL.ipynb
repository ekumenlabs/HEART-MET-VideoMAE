# %%
#!pip install torch torchvision torchaudio
import torch
print('gpu?'+str(torch.cuda.is_available()))
# Out:
# gpu?True

# %% [markdown]
# ## Colab Configuration

# %%
names=['Opening the door and walking in/out',
        'Putting on a jacket',
        'Touching a hot surface',
        'Opening the fridge',
        'Drinking water',
        'Colliding against something',
        'Eating food with a fork',
        'Coughing or sneezing',
        'Wiping a table',
        'Reading a book',
        'Neck roll exercise',
        'Freehand exercise',
        'Lying down',
        'Limping',
        'Talking on the phone',
        'Using a computer',
        'Falling down',
        'Brushing teeth',
        'Writing',
        'Unknown activity']

# %% [markdown]
# The next code is adapted from (higgingFace->VideMAE-> VideoMAEForVideoClassification)[https://huggingface.co/docs/transformers/main/en/model_doc/videomae#transformers.VideoMAEForVideoClassification]

# %%
from decord import VideoReader, cpu
from transformers import VideoMAEFeatureExtractor, VideoMAEForPreTraining,VideoMAEConfig,VideoMAEForVideoClassification
import numpy as np
import torch
import os
import json
import csv #I make in a venv here more easy pandas...

# %%
name_model="MCG-NJU/videomae-base-finetuned-kinetics"
#name_model="MCG-NJU/videomae-base"
feature_extractor = VideoMAEFeatureExtractor.from_pretrained(name_model)
output=json.load(open('training_labels.json'))
validation_labels = json.load(open('validation_labels.json'))
path='training_set'
validation_path='validation_set'

# %% [markdown]
# ## Fine tuning VideoMAE
#
# Fine tuning is the gold of transformers, from few videos/images/sentences we can make a classifier.
#
# VideoMAE is based of a ImageMAE which is based in ViT (Vision Transformer), which is Based in Transformers, so let try.

# %% [markdown]
# ### Create DataSet
#
# based in [image dataset](https://huggingface.co/docs/datasets/image_dataset). I think that it is not used in the best way the library [link text](https://huggingface.co/course/chapter5/4?fw=pt)

# %%
from datasets import Dataset
import numpy as np

my_set=[{'file_name':path+'/'+a,'labels':output[a][0],'description':names[output[a][0]]} for a in output.keys()]
validation_set=[{'file_name':validation_path+'/'+a,'labels':validation_labels[a][0],'description':names[validation_labels[a][0]]} for a in validation_labels.keys()]

# %%
from tqdm.notebook import tqdm

augmented_set = []
for elem in tqdm(my_set):
    file_path = elem['file_name']
    videoreader = VideoReader(file_path, num_threads=1, ctx=cpu(0))
    videoreader.seek(0)
    file_size = len(videoreader)
    batches = int(file_size/16)
    for i in range(batches):
        new_elem = {}
        new_elem['file_name'] = file_path + '@' + str(i)
        new_elem['labels'] = elem['labels']
        augmented_set.append(new_elem)
# Out:
#   0%|          | 0/792 [00:00<?, ?it/s]

# %%
augmented_validation_set = []
for elem in tqdm(validation_set):
    file_path = elem['file_name']
    videoreader = VideoReader(file_path, num_threads=1, ctx=cpu(0))
    videoreader.seek(0)
    file_size = len(videoreader)
    batches = int(file_size/16)
    for i in range(batches):
        new_elem = {}
        new_elem['file_name'] = file_path + '@' + str(i)
        new_elem['labels'] = elem['labels']
        augmented_validation_set.append(new_elem)
# Out:
#   0%|          | 0/136 [00:00<?, ?it/s]

# %%
len(augmented_set)
# Out:
# 7148

# %%
len(augmented_validation_set)
# Out:
# 1220

# %%
# from sklearn.model_selection import train_test_split
# my_set_trian,my_set_val =train_test_split(augmented_set, test_size=0.2, random_state=42)

# %%
# all_set = {}
# full_train_set = {}

# all_set['train'] = my_set_trian
# all_set['validation'] = my_set_val
# full_train_set['train'] = augmented_set

full_augmented_set = {}
full_augmented_set['train'] = augmented_set
full_augmented_set['validation'] = augmented_validation_set

with open("train_augmented.json", "w") as final:
    json.dump(full_augmented_set, final)
    
# with open("full_train.json", "w") as final:
#     json.dump(full_train_set, final)

# %%
# dataset = Dataset.from_json('train.json',field='train')
# dataset_validation = Dataset.from_json('train.json',field='validation')
# dataset_full = Dataset.from_json('full_train.json', field='train')
dataset = Dataset.from_json('train_augmented.json',field='train')
dataset_validation = Dataset.from_json('train_augmented.json',field='validation')
# Out:
# Using custom data configuration default-27712e88fc2a575c
# Downloading and preparing dataset json/default to /home/tomas/.cache/huggingface/datasets/json/default-27712e88fc2a575c/0.0.0...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Using custom data configuration default-99d1998bd928da80
# Dataset json downloaded and prepared to /home/tomas/.cache/huggingface/datasets/json/default-27712e88fc2a575c/0.0.0. Subsequent calls will reuse this data.
# Downloading and preparing dataset json/default to /home/tomas/.cache/huggingface/datasets/json/default-99d1998bd928da80/0.0.0...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset json downloaded and prepared to /home/tomas/.cache/huggingface/datasets/json/default-99d1998bd928da80/0.0.0. Subsequent calls will reuse this data.

# %%
dataset[0]
# Out:
# {'file_name': 'training_set/video0000.mp4@0', 'labels': 14}

# %%
# for i in range(int(144/16)):
#     sub = int(144/16)
#     indices = np.linspace(i, 144-sub+i, num=16)
#     indices = np.clip(indices, 0, 144- 1).astype(np.int64)
#     print(indices)

# %%
# def multi_sample(pre_dataset):
#     new_dataset = []
#     for elem in tqdm(pre_dataset):
#         file_path = elem['file_name']
#         videoreader = VideoReader(file_path, num_threads=1, ctx=cpu(0))
#         videoreader.seek(0)
#         file_size = len(videoreader)
#         batches = int(file_size/16)
#         for i in range(batches):
#             indices = np.linspace(i, len(videoreader)-batches+i, num=16)
#             indices = np.clip(indices, 0, len(videoreader)- 1).astype(np.int64)
#             output = {}
#             output['pixel_values'] = feature_extractor(list(videoreader.get_batch(indices).asnumpy()), return_tensors="pt")['pixel_values'][0]
#             output['labels'] = elem['labels']
#             new_dataset.append(output)
#     return new_dataset

# %%
# prepared_train = multi_sample(dataset)
# prepared_validation = multi_sample(dataset_validation)
# prepared_full = multi_sample(dataset_full)
# TAKES TOO MUCH RAM, IMMPOSIBLE

# %%
# def transform(sample):
#     """
#     TODO: test different sampling methods
#     """
#     inputs=[]
    
#     for s in sample['file_name']:
#       videoreader = VideoReader(s, num_threads=1, ctx=cpu(0))
#       videoreader.seek(0)
#       #indices = sample_frame_indices(clip_len=16, frame_sample_rate=4, seg_len=len(videoreader))
#       indices = np.linspace(0, len(videoreader), num=16)
#       indices = np.clip(indices, 0, len(videoreader)- 1).astype(np.int64)
#       inputs.append(feature_extractor(list(videoreader.get_batch(indices).asnumpy()), return_tensors="pt")['pixel_values'][0])
#     output={}  
#     output['pixel_values'] =inputs 
#     # Don't forget to include the labels!
#     output['labels'] = sample['labels']
#     return output

# %%
# prepared_train = dataset.with_transform(transform)
# prepared_validation = dataset_validation.with_transform(transform)
# prepared_full = dataset_full.with_transform(transform)

# %%
# prepared_train[0]

# %%
import cv2 as cv

# params for ShiTomasi corner detection
feature_params = dict( maxCorners = 100,
                       qualityLevel = 0.3,
                       minDistance = 7,
                       blockSize = 7 )
# Parameters for lucas kanade optical flow
lk_params = dict( winSize  = (15, 15),
                  maxLevel = 2,
                  criteria = (cv.TERM_CRITERIA_EPS | cv.TERM_CRITERIA_COUNT, 10, 0.03))

def optical_flow(video):
    temp_video = videoreader[:].asnumpy()
    old_gray = cv.cvtColor(temp_video[0], cv.COLOR_BGR2GRAY)
    p0 = cv.goodFeaturesToTrack(old_gray, mask = None, **feature_params)
    output = []
    for frame in temp_video[1:]:
        frame_gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
        # calculate optical flow
        p1, st, err = cv.calcOpticalFlowPyrLK(old_gray, frame_gray, p0, None, **lk_params)
        # Select good points
        mask = np.zeros_like(old_gray)
        if p1 is not None:
            good_new = p1[st==1]
            good_old = p0[st==1]
        for i, (new, old) in enumerate(zip(good_new, good_old)):
            a, b = new.ravel()
            c, d = old.ravel()
            mask = cv.line(mask, (int(a), int(b)), (int(c), int(d)), 255, 2)
            mask = cv.circle(mask, (int(a), int(b)), 5, 255, -1)
        # Now update the previous frame and previous points
        output.append(mask)
        old_gray = frame_gray.copy()
        p0 = good_new.reshape(-1, 1, 2)
    return np.asarray(output)

# %%
videoreader = VideoReader(my_set[0]['file_name'], num_threads=1, ctx=cpu(0))
videoreader.seek(0)

optical_output = optical_flow(videoreader[:].asnumpy())

# %%
import matplotlib.pyplot as plt
print(videoreader[:].asnumpy().shape)
print(optical_output.shape)
plt.imshow(optical_output[0])
# Out:
# (140, 480, 640, 3)
# (139, 480, 640)

# %% [markdown]
# ### Training and validation
#
# Based in [Fine tuning ViT](https://huggingface.co/blog/fine-tune-vit)

# %%
import torch

# def collate_fn(batch):
    
#     return {
#         'pixel_values': torch.stack([x['pixel_values'] for x in batch]),
#         'labels': torch.tensor([x['labels'] for x in batch])
#     }

# %%
# def collate_multi_with_path_batches(batch):
#     pixel_values = []
#     labels = []
#     for elem in batch:
#         file_path = elem['file_name']
#         videoreader = VideoReader(file_path, num_threads=1, ctx=cpu(0))
#         videoreader.seek(0)
#         file_size = len(videoreader)
#         batches = int(file_size/16)
#         for i in range(batches):
#             indices = np.linspace(i, len(videoreader)-batches+i, num=16)
#             indices = np.clip(indices, 0, len(videoreader)- 1).astype(np.int64)
#             pixel_values.append(feature_extractor(list(videoreader.get_batch(indices).asnumpy()), return_tensors="pt")['pixel_values'][0])
#             labels.append(elem['labels'])
#     return {
#         'pixel_values': torch.stack(pixel_values),
#         'labels': torch.tensor(labels)
#     }

# %%
def collate_with_path_batches(batch):
    pixel_values = []
    labels = []
    for elem in batch:
        file_path, i = elem['file_name'].split('@')
        i = int(i)
        videoreader = VideoReader(file_path, num_threads=1, ctx=cpu(0))
        videoreader.seek(0)
        file_size = len(videoreader)
        batches = int(file_size/16)
        indices = np.linspace(i, len(videoreader)-batches+i, num=16)
        indices = np.clip(indices, 0, len(videoreader)- 1).astype(np.int64)
        pixel_values.append(feature_extractor(list(videoreader.get_batch(indices).asnumpy()), return_tensors="pt")['pixel_values'][0])
        labels.append(elem['labels'])
    return {
        'pixel_values': torch.stack(pixel_values),
        'labels': torch.tensor(labels)
    }

# %%
import numpy as np
from datasets import load_metric

metric = load_metric("accuracy")
def compute_metrics(p):
    return metric.compute(predictions=np.argmax(p.predictions, axis=1), references=p.label_ids)
# Out:
# /tmp/ipykernel_3808937/2425197347.py:4: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric("accuracy")

# %%
labels = names

model = VideoMAEForVideoClassification.from_pretrained(
    name_model,
    num_labels=len(labels),
    id2label={str(i): c for i, c in enumerate(labels)},
    label2id={c: str(i) for i, c in enumerate(labels)},
    ignore_mismatched_sizes=True,
#     patch_size = 32,
#     num_frames = 64
)
# Out:
# Some weights of VideoMAEForVideoClassification were not initialized from the model checkpoint at MCG-NJU/videomae-base-finetuned-kinetics and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([400, 768]) in the checkpoint and torch.Size([20, 768]) in the model instantiated
# - classifier.bias: found shape torch.Size([400]) in the checkpoint and torch.Size([20]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
for name, param in model.named_parameters():
    if param.requires_grad:
        if 'videomae' in name or 'fc_norm' in name:
            param.requires_grad = False
            
for name, param in model.named_parameters():
    if param.requires_grad:
        print(name)

# for name, param in model.named_parameters():
#     if param.requires_grad:
#         if 'videomae' in name:
#             param.requires_grad = False
            
# for name, param in model.named_parameters():
#     if param.requires_grad:
#         print(name)
# Out:
# classifier.weight
# classifier.bias

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
  output_dir="./videomae-icsr-heart",
  per_device_train_batch_size=16,
  per_device_eval_batch_size=16,
  evaluation_strategy="steps",
  num_train_epochs=12,
  fp16=True,
  save_steps=50,
  eval_steps=50,
  logging_steps=50,
#   weight_decay =0.05,
#   learning_rate=1e-5,
  save_total_limit=5,
  remove_unused_columns=False,
  push_to_hub=False,
  #report_to='tensorboard',
  load_best_model_at_end=True,
)

# %%
# from transformers import TrainingArguments

# training_args = TrainingArguments(
#   output_dir="./videomae-icsr-heart",
#   per_device_train_batch_size=2,
#   num_train_epochs=16,
#   save_steps=198,
#   logging_steps=198,
#   save_total_limit=5,
#   remove_unused_columns=False,
# )

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=collate_with_path_batches,
    compute_metrics=compute_metrics,
    train_dataset=dataset,
    eval_dataset=dataset_validation,
    tokenizer=feature_extractor,
)
# Out:
# Using cuda_amp half precision backend

# %%
torch.cuda.empty_cache()

# %%
train_results = trainer.train()
# Out:
# /home/tomas/.local/lib/python3.8/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 7148
#   Num Epochs = 12
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 5364
#   Number of trainable parameters = 15380
#     <div>
#
#       <progress value='5364' max='5364' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5364/5364 6:20:29, Epoch 12/12]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>2.837000</td>
#       <td>2.876852</td>
#       <td>0.113115</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>2.663000</td>
#       <td>2.762153</td>
#       <td>0.163115</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>2.508600</td>
#       <td>2.663036</td>
#       <td>0.204918</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>2.337300</td>
#       <td>2.568589</td>
#       <td>0.259836</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>2.224900</td>
#       <td>2.485153</td>
#       <td>0.336066</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>2.107300</td>
#       <td>2.410009</td>
#       <td>0.395902</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.993100</td>
#       <td>2.335044</td>
#       <td>0.444262</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.881200</td>
#       <td>2.268728</td>
#       <td>0.483607</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.787800</td>
#       <td>2.205790</td>
#       <td>0.501639</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.692900</td>
#       <td>2.146368</td>
#       <td>0.512295</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>1.667100</td>
#       <td>2.093621</td>
#       <td>0.528689</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.566000</td>
#       <td>2.042138</td>
#       <td>0.536885</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>1.502200</td>
#       <td>1.992899</td>
#       <td>0.545902</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>1.446600</td>
#       <td>1.948780</td>
#       <td>0.559836</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>1.370000</td>
#       <td>1.903027</td>
#       <td>0.575410</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.313700</td>
#       <td>1.861789</td>
#       <td>0.585246</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>1.283100</td>
#       <td>1.826265</td>
#       <td>0.588525</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>1.250100</td>
#       <td>1.794728</td>
#       <td>0.592623</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>1.198700</td>
#       <td>1.762528</td>
#       <td>0.594262</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.145500</td>
#       <td>1.728721</td>
#       <td>0.604098</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>1.116600</td>
#       <td>1.703942</td>
#       <td>0.608197</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>1.071800</td>
#       <td>1.675672</td>
#       <td>0.611475</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>1.044300</td>
#       <td>1.647432</td>
#       <td>0.616393</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>1.015400</td>
#       <td>1.620778</td>
#       <td>0.619672</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>1.025200</td>
#       <td>1.598175</td>
#       <td>0.623770</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.974100</td>
#       <td>1.579370</td>
#       <td>0.622131</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.915700</td>
#       <td>1.559178</td>
#       <td>0.617213</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.905900</td>
#       <td>1.541087</td>
#       <td>0.622131</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.874300</td>
#       <td>1.523209</td>
#       <td>0.625410</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.881000</td>
#       <td>1.504008</td>
#       <td>0.626230</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.844600</td>
#       <td>1.485146</td>
#       <td>0.630328</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.857500</td>
#       <td>1.471036</td>
#       <td>0.640164</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.844800</td>
#       <td>1.455855</td>
#       <td>0.634426</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.805200</td>
#       <td>1.442334</td>
#       <td>0.631967</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.770300</td>
#       <td>1.429134</td>
#       <td>0.625410</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.800500</td>
#       <td>1.415704</td>
#       <td>0.638525</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.782800</td>
#       <td>1.400973</td>
#       <td>0.648361</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.733400</td>
#       <td>1.390197</td>
#       <td>0.645902</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.714400</td>
#       <td>1.376707</td>
#       <td>0.651639</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.711600</td>
#       <td>1.367251</td>
#       <td>0.653279</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.718500</td>
#       <td>1.357147</td>
#       <td>0.654098</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.723200</td>
#       <td>1.350250</td>
#       <td>0.654918</td>
#     </tr>
#     <tr>
#       <td>2150</td>
#       <td>0.697600</td>
#       <td>1.341044</td>
#       <td>0.654098</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.668700</td>
#       <td>1.333772</td>
#       <td>0.654098</td>
#     </tr>
#     <tr>
#       <td>2250</td>
#       <td>0.652500</td>
#       <td>1.325303</td>
#       <td>0.654918</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.658700</td>
#       <td>1.317310</td>
#       <td>0.657377</td>
#     </tr>
#     <tr>
#       <td>2350</td>
#       <td>0.646900</td>
#       <td>1.309569</td>
#       <td>0.658197</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.650900</td>
#       <td>1.301190</td>
#       <td>0.659016</td>
#     </tr>
#     <tr>
#       <td>2450</td>
#       <td>0.618800</td>
#       <td>1.293555</td>
#       <td>0.660656</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.633900</td>
#       <td>1.287310</td>
#       <td>0.660656</td>
#     </tr>
#     <tr>
#       <td>2550</td>
#       <td>0.661200</td>
#       <td>1.281279</td>
#       <td>0.662295</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.599000</td>
#       <td>1.276651</td>
#       <td>0.660656</td>
#     </tr>
#     <tr>
#       <td>2650</td>
#       <td>0.576500</td>
#       <td>1.271700</td>
#       <td>0.663934</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.609400</td>
#       <td>1.264701</td>
#       <td>0.663934</td>
#     </tr>
#     <tr>
#       <td>2750</td>
#       <td>0.584000</td>
#       <td>1.258952</td>
#       <td>0.665574</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.617400</td>
#       <td>1.251137</td>
#       <td>0.663934</td>
#     </tr>
#     <tr>
#       <td>2850</td>
#       <td>0.540000</td>
#       <td>1.246015</td>
#       <td>0.665574</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.557700</td>
#       <td>1.242003</td>
#       <td>0.665574</td>
#     </tr>
#     <tr>
#       <td>2950</td>
#       <td>0.566500</td>
#       <td>1.237994</td>
#       <td>0.663115</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.570100</td>
#       <td>1.233375</td>
#       <td>0.665574</td>
#     </tr>
#     <tr>
#       <td>3050</td>
#       <td>0.550400</td>
#       <td>1.229795</td>
#       <td>0.667213</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.596100</td>
#       <td>1.224787</td>
#       <td>0.666393</td>
#     </tr>
#     <tr>
#       <td>3150</td>
#       <td>0.562200</td>
#       <td>1.221752</td>
#       <td>0.667213</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.560600</td>
#       <td>1.216995</td>
#       <td>0.665574</td>
#     </tr>
#     <tr>
#       <td>3250</td>
#       <td>0.554600</td>
#       <td>1.212687</td>
#       <td>0.665574</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.555800</td>
#       <td>1.209369</td>
#       <td>0.666393</td>
#     </tr>
#     <tr>
#       <td>3350</td>
#       <td>0.546600</td>
#       <td>1.204417</td>
#       <td>0.668033</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.523800</td>
#       <td>1.202437</td>
#       <td>0.666393</td>
#     </tr>
#     <tr>
#       <td>3450</td>
#       <td>0.519800</td>
#       <td>1.199298</td>
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-50
# Configuration saved in ./videomae-icsr-heart/checkpoint-50/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-50/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-50/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-2100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-100
# Configuration saved in ./videomae-icsr-heart/checkpoint-100/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-100/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-100/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-5200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-150
# Configuration saved in ./videomae-icsr-heart/checkpoint-150/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-150/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-150/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-5250] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-200
# Configuration saved in ./videomae-icsr-heart/checkpoint-200/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-200/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-200/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-5300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-250
# Configuration saved in ./videomae-icsr-heart/checkpoint-250/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-250/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-250/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-5350] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-300
# Configuration saved in ./videomae-icsr-heart/checkpoint-300/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-300/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-300/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-50] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-350
# Configuration saved in ./videomae-icsr-heart/checkpoint-350/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-350/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-350/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-400
# Configuration saved in ./videomae-icsr-heart/checkpoint-400/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-400/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-400/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-150] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-450
# Configuration saved in ./videomae-icsr-heart/checkpoint-450/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-450/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-450/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-500
# Configuration saved in ./videomae-icsr-heart/checkpoint-500/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-500/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-500/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-250] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-550
# Configuration saved in ./videomae-icsr-heart/checkpoint-550/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-550/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-550/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-600
# Configuration saved in ./videomae-icsr-heart/checkpoint-600/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-600/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-600/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-350] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-650
# Configuration saved in ./videomae-icsr-heart/checkpoint-650/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-650/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-650/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-700
# Configuration saved in ./videomae-icsr-heart/checkpoint-700/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-700/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-700/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-450] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-750
# Configuration saved in ./videomae-icsr-heart/checkpoint-750/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-750/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-750/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-800
# Configuration saved in ./videomae-icsr-heart/checkpoint-800/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-800/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-800/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-550] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-850
# Configuration saved in ./videomae-icsr-heart/checkpoint-850/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-850/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-850/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-900
# Configuration saved in ./videomae-icsr-heart/checkpoint-900/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-900/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-900/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-650] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-950
# Configuration saved in ./videomae-icsr-heart/checkpoint-950/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-950/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-950/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-1000
# Configuration saved in ./videomae-icsr-heart/checkpoint-1000/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-1000/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-1000/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-750] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-1050
# Configuration saved in ./videomae-icsr-heart/checkpoint-1050/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-1050/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-1050/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-1100
# Configuration saved in ./videomae-icsr-heart/checkpoint-1100/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-1100/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-1100/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-850] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-1150
# Configuration saved in ./videomae-icsr-heart/checkpoint-1150/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-1150/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-1150/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-1200
# Configuration saved in ./videomae-icsr-heart/checkpoint-1200/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-1200/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-1200/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-950] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-1250
# Configuration saved in ./videomae-icsr-heart/checkpoint-1250/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-1250/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-1250/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-1000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-1300
# Configuration saved in ./videomae-icsr-heart/checkpoint-1300/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-1300/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-1300/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-1050] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-1350
# Configuration saved in ./videomae-icsr-heart/checkpoint-1350/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-1350/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-1350/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-1100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-1400
# Configuration saved in ./videomae-icsr-heart/checkpoint-1400/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-1400/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-1400/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-1150] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-1450
# Configuration saved in ./videomae-icsr-heart/checkpoint-1450/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-1450/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-1450/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-1200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-1500
# Configuration saved in ./videomae-icsr-heart/checkpoint-1500/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-1500/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-1500/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-1250] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-1550
# Configuration saved in ./videomae-icsr-heart/checkpoint-1550/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-1550/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-1550/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-1300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-1600
# Configuration saved in ./videomae-icsr-heart/checkpoint-1600/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-1600/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-1600/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-1350] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-1650
# Configuration saved in ./videomae-icsr-heart/checkpoint-1650/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-1650/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-1650/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-1400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-1700
# Configuration saved in ./videomae-icsr-heart/checkpoint-1700/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-1700/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-1700/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-1450] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-1750
# Configuration saved in ./videomae-icsr-heart/checkpoint-1750/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-1750/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-1750/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-1500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-1800
# Configuration saved in ./videomae-icsr-heart/checkpoint-1800/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-1800/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-1800/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-1550] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-1850
# Configuration saved in ./videomae-icsr-heart/checkpoint-1850/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-1850/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-1850/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-1600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-1900
# Configuration saved in ./videomae-icsr-heart/checkpoint-1900/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-1900/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-1900/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-1650] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-1950
# Configuration saved in ./videomae-icsr-heart/checkpoint-1950/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-1950/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-1950/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-1700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-2000
# Configuration saved in ./videomae-icsr-heart/checkpoint-2000/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-2000/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-2000/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-1750] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-2050
# Configuration saved in ./videomae-icsr-heart/checkpoint-2050/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-2050/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-2050/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-1800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-2100
# Configuration saved in ./videomae-icsr-heart/checkpoint-2100/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-2100/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-2100/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-1850] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-2150
# Configuration saved in ./videomae-icsr-heart/checkpoint-2150/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-2150/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-2150/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-1900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-2200
# Configuration saved in ./videomae-icsr-heart/checkpoint-2200/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-2200/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-2200/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-1950] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-2250
# Configuration saved in ./videomae-icsr-heart/checkpoint-2250/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-2250/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-2250/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-2000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-2300
# Configuration saved in ./videomae-icsr-heart/checkpoint-2300/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-2300/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-2300/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-2050] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-2350
# Configuration saved in ./videomae-icsr-heart/checkpoint-2350/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-2350/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-2350/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-2100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-2400
# Configuration saved in ./videomae-icsr-heart/checkpoint-2400/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-2400/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-2400/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-2150] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-2450
# Configuration saved in ./videomae-icsr-heart/checkpoint-2450/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-2450/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-2450/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-2200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-2500
# Configuration saved in ./videomae-icsr-heart/checkpoint-2500/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-2500/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-2500/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-2250] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-2550
# Configuration saved in ./videomae-icsr-heart/checkpoint-2550/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-2550/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-2550/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-2300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-2600
# Configuration saved in ./videomae-icsr-heart/checkpoint-2600/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-2600/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-2600/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-2350] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-2650
# Configuration saved in ./videomae-icsr-heart/checkpoint-2650/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-2650/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-2650/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-2400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-2700
# Configuration saved in ./videomae-icsr-heart/checkpoint-2700/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-2700/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-2700/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-2450] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-2750
# Configuration saved in ./videomae-icsr-heart/checkpoint-2750/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-2750/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-2750/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-2500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-2800
# Configuration saved in ./videomae-icsr-heart/checkpoint-2800/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-2800/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-2800/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-2550] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-2850
# Configuration saved in ./videomae-icsr-heart/checkpoint-2850/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-2850/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-2850/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-2600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-2900
# Configuration saved in ./videomae-icsr-heart/checkpoint-2900/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-2900/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-2900/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-2650] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-2950
# Configuration saved in ./videomae-icsr-heart/checkpoint-2950/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-2950/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-2950/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-2700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-3000
# Configuration saved in ./videomae-icsr-heart/checkpoint-3000/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-3000/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-3000/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-2750] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-3050
# Configuration saved in ./videomae-icsr-heart/checkpoint-3050/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-3050/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-3050/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-2800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-3100
# Configuration saved in ./videomae-icsr-heart/checkpoint-3100/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-3100/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-3100/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-2850] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-3150
# Configuration saved in ./videomae-icsr-heart/checkpoint-3150/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-3150/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-3150/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-2900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-3200
# Configuration saved in ./videomae-icsr-heart/checkpoint-3200/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-3200/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-3200/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-2950] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-3250
# Configuration saved in ./videomae-icsr-heart/checkpoint-3250/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-3250/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-3250/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-3000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-3300
# Configuration saved in ./videomae-icsr-heart/checkpoint-3300/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-3300/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-3300/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-3050] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-3350
# Configuration saved in ./videomae-icsr-heart/checkpoint-3350/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-3350/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-3350/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-3100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-3400
# Configuration saved in ./videomae-icsr-heart/checkpoint-3400/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-3400/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-3400/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-3150] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-3450
# Configuration saved in ./videomae-icsr-heart/checkpoint-3450/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-3450/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-3450/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-3200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-3500
# Configuration saved in ./videomae-icsr-heart/checkpoint-3500/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-3500/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-3500/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-3250] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-3550
# Configuration saved in ./videomae-icsr-heart/checkpoint-3550/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-3550/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-3550/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-3300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-3600
# Configuration saved in ./videomae-icsr-heart/checkpoint-3600/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-3600/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-3600/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-3350] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-3650
# Configuration saved in ./videomae-icsr-heart/checkpoint-3650/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-3650/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-3650/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-3400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-3700
# Configuration saved in ./videomae-icsr-heart/checkpoint-3700/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-3700/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-3700/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-3450] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-3750
# Configuration saved in ./videomae-icsr-heart/checkpoint-3750/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-3750/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-3750/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-3500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-3800
# Configuration saved in ./videomae-icsr-heart/checkpoint-3800/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-3800/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-3800/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-3550] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-3850
# Configuration saved in ./videomae-icsr-heart/checkpoint-3850/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-3850/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-3850/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-3600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-3900
# Configuration saved in ./videomae-icsr-heart/checkpoint-3900/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-3900/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-3900/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-3650] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-3950
# Configuration saved in ./videomae-icsr-heart/checkpoint-3950/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-3950/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-3950/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-3700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-4000
# Configuration saved in ./videomae-icsr-heart/checkpoint-4000/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-4000/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-4000/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-3750] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-4050
# Configuration saved in ./videomae-icsr-heart/checkpoint-4050/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-4050/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-4050/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-3800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-4100
# Configuration saved in ./videomae-icsr-heart/checkpoint-4100/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-4100/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-4100/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-3850] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-4150
# Configuration saved in ./videomae-icsr-heart/checkpoint-4150/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-4150/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-4150/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-3900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-4200
# Configuration saved in ./videomae-icsr-heart/checkpoint-4200/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-4200/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-4200/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-3950] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-4250
# Configuration saved in ./videomae-icsr-heart/checkpoint-4250/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-4250/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-4250/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-4000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-4300
# Configuration saved in ./videomae-icsr-heart/checkpoint-4300/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-4300/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-4300/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-4050] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-4350
# Configuration saved in ./videomae-icsr-heart/checkpoint-4350/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-4350/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-4350/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-4100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-4400
# Configuration saved in ./videomae-icsr-heart/checkpoint-4400/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-4400/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-4400/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-4150] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-4450
# Configuration saved in ./videomae-icsr-heart/checkpoint-4450/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-4450/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-4450/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-4200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-4500
# Configuration saved in ./videomae-icsr-heart/checkpoint-4500/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-4500/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-4500/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-4250] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-4550
# Configuration saved in ./videomae-icsr-heart/checkpoint-4550/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-4550/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-4550/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-4300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-4600
# Configuration saved in ./videomae-icsr-heart/checkpoint-4600/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-4600/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-4600/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-4350] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-4650
# Configuration saved in ./videomae-icsr-heart/checkpoint-4650/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-4650/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-4650/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-4400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-4700
# Configuration saved in ./videomae-icsr-heart/checkpoint-4700/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-4700/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-4700/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-4450] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-4750
# Configuration saved in ./videomae-icsr-heart/checkpoint-4750/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-4750/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-4750/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-4500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-4800
# Configuration saved in ./videomae-icsr-heart/checkpoint-4800/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-4800/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-4800/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-4550] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-4850
# Configuration saved in ./videomae-icsr-heart/checkpoint-4850/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-4850/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-4850/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-4600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-4900
# Configuration saved in ./videomae-icsr-heart/checkpoint-4900/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-4900/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-4900/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-4650] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-4950
# Configuration saved in ./videomae-icsr-heart/checkpoint-4950/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-4950/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-4950/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-4700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-5000
# Configuration saved in ./videomae-icsr-heart/checkpoint-5000/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-5000/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-5000/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-4750] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-5050
# Configuration saved in ./videomae-icsr-heart/checkpoint-5050/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-5050/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-5050/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-4800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-5100
# Configuration saved in ./videomae-icsr-heart/checkpoint-5100/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-5100/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-5100/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-4850] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-5150
# Configuration saved in ./videomae-icsr-heart/checkpoint-5150/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-5150/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-5150/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-4900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-5200
# Configuration saved in ./videomae-icsr-heart/checkpoint-5200/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-5200/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-5200/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-4950] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-5250
# Configuration saved in ./videomae-icsr-heart/checkpoint-5250/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-5250/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-5250/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-5000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-5300
# Configuration saved in ./videomae-icsr-heart/checkpoint-5300/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-5300/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-5300/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-5050] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1220
#   Batch size = 16
# Saving model checkpoint to ./videomae-icsr-heart/checkpoint-5350
# Configuration saved in ./videomae-icsr-heart/checkpoint-5350/config.json
# Model weights saved in ./videomae-icsr-heart/checkpoint-5350/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/checkpoint-5350/preprocessor_config.json
# Deleting older checkpoint [videomae-icsr-heart/checkpoint-5100] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./videomae-icsr-heart/checkpoint-5350 (score: 1.1446717977523804).

# %%
trainer.save_model()
trainer.log_metrics("train", train_results.metrics)
trainer.save_metrics("train", train_results.metrics)
trainer.save_state()
# Out:
# Saving model checkpoint to ./videomae-icsr-heart
# Configuration saved in ./videomae-icsr-heart/config.json
# Model weights saved in ./videomae-icsr-heart/pytorch_model.bin
# Feature extractor saved in ./videomae-icsr-heart/preprocessor_config.json
# ***** train metrics *****
#   epoch                    =           4.0
#   total_flos               = 33186001607GF
#   train_loss               =         1.424
#   train_runtime            =    1:07:49.50
#   train_samples_per_second =         7.026
#   train_steps_per_second   =          0.22

# %%
metrics = trainer.evaluate(dataset_validation)
trainer.log_metrics("eval", metrics)
trainer.save_metrics("eval", metrics)

# %%
metrics
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [30], line 1
# ----> 1 metrics
#
# NameError: name 'metrics' is not defined

# %%
kwargs = {
    "finetuned_from": model.config._name_or_path,
    "tasks": "video-classification",
    "dataset": 'HEART-MET',
    "tags": ['video-classification'],
}

trainer.create_model_card(**kwargs)

# %%
#!cp -R /content/videomae-icsr-heart/ /content/drive/MyDrive/ICSR 2022 HEART-MET Activity Recognition Challenge/models
# !cp -R /content/videomae-icsr-heart/ /content/drive/MyDrive/models/

# %% [markdown]
# ## testing

# %%
# prepared_validation.to_json('/content/validation_set.csv')

# %%
prepared_train.to_json('/content/training_set.csv')
# Out:
# Creating json from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 56355

# %%
data['pixel_values']

# %%
i=0
predicted=[]
for data in all_set['validation']:
  #if i==2:
  #  break
  i+=1
  videoreader = VideoReader(data['file_name'], num_threads=1, ctx=cpu(0))
  videoreader.seek(0)
  #indices = sample_frame_indices(clip_len=16, frame_sample_rate=4, seg_len=len(videoreader))
  indices = np.linspace(0, len(videoreader), num=16)
  indices = np.clip(indices, 0, len(videoreader)- 1).astype(np.int64)
  pixel_values = feature_extractor(list(videoreader.get_batch(indices).asnumpy()), return_tensors="pt")
  pixel_values = pixel_values.to('cuda')
  with torch.no_grad():
        outputs = model(**pixel_values)#
        pred=outputs.logits.argmax(-1).item()
        predicted.append([data['file_name'],data['labels'],data['description'],pred])
        print(data['labels'],pred)
# Out:
# 6 6
# 4 4
# 12 12
# 8 8
# 9 9
# 15 15
# 6 6
# 0 0
# 8 8
# 18 18
# 15 15
# 8 8
# 15 15
# 17 17
# 17 17
# 6 6
# 4 4
# 4 4
# 1 1
# 8 8
# 14 14
# 12 12
# 7 7
# 12 12
# 4 4
# 4 4
# 15 15
# 17 17
# 11 11
# 12 12
# 14 14
# 18 18
# 6 6
# 19 19
# 6 6
# 14 14
# 5 5
# 15 15
# 6 6
# 6 6
# 6 6
# 1 1
# 4 4
# 12 12
# 18 18
# 7 7
# 13 13
# 0 0
# 3 3
# 6 6
# 9 9
# 15 15
# 14 14
# 17 17
# 9 9
# 6 6
# 17 17
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [141], line 12
#      10 indices = np.linspace(0, len(videoreader), num=128)
#      11 indices = np.clip(indices, 0, len(videoreader)- 1).astype(np.int64)
# ---> 12 pixel_values = feature_extractor(list(videoreader.get_batch(indices).asnumpy()), return_tensors="pt")
#      13 pixel_values = pixel_values.to('cuda')
#      14 with torch.no_grad():
#
# File ~/.local/lib/python3.8/site-packages/transformers/models/videomae/feature_extraction_videomae.py:166, in VideoMAEFeatureExtractor.__call__(self, videos, return_tensors, **kwargs)
#     164     videos = [self.crop_video(video, size=self.size) for video in videos]
#     165 if self.do_normalize:
# --> 166     videos = [self.normalize_video(video, mean=self.image_mean, std=self.image_std) for video in videos]
#     168 # return as BatchFeature
#     169 data = {"pixel_values": videos}
#
# File ~/.local/lib/python3.8/site-packages/transformers/models/videomae/feature_extraction_videomae.py:166, in <listcomp>(.0)
#     164     videos = [self.crop_video(video, size=self.size) for video in videos]
#     165 if self.do_normalize:
# --> 166     videos = [self.normalize_video(video, mean=self.image_mean, std=self.image_std) for video in videos]
#     168 # return as BatchFeature
#     169 data = {"pixel_values": videos}
#
# File ~/.local/lib/python3.8/site-packages/transformers/models/videomae/feature_extraction_videomae.py:101, in VideoMAEFeatureExtractor.normalize_video(self, video, mean, std)
#      98 if not isinstance(std, np.ndarray):
#      99     std = np.array(std).astype(video.dtype)
# --> 101 return (video - mean[None, :, None, None]) / std[None, :, None, None]
#
# KeyboardInterrupt:

# %%
import pandas as pd
df = pd.DataFrame(predicted,columns=['file','label','description','predicted'])

df
# Out:
#                            file  label              description  predicted
# 0    training_set/video0694.mp4      6  Eating food with a fork          6
# 1    training_set/video0528.mp4      4           Drinking water          4
# 2    training_set/video0598.mp4     12               Lying down         12
# 3    training_set/video0606.mp4      8           Wiping a table          7
# 4    training_set/video0120.mp4      9           Reading a book          9
# ..                          ...    ...                      ...        ...
# 154  training_set/video0433.mp4     15         Using a computer         15
# 155  training_set/video0467.mp4     17           Brushing teeth         17
# 156  training_set/video0361.mp4     12               Lying down         12
# 157  training_set/video0079.mp4      1      Putting on a jacket          1
# 158  training_set/video0148.mp4     15         Using a computer         15
#
# [159 rows x 4 columns]

# %%
from sklearn.metrics import classification_report

print(classification_report(df['label'], df['predicted'], target_names=names))
# Out:
#                                      precision    recall  f1-score   support
#
# Opening the door and walking in/out       1.00      1.00      1.00         7
#                 Putting on a jacket       1.00      0.88      0.93         8
#              Touching a hot surface       0.75      1.00      0.86         3
#                  Opening the fridge       1.00      1.00      1.00         3
#                      Drinking water       1.00      1.00      1.00        15
#         Colliding against something       0.50      1.00      0.67         2
#             Eating food with a fork       0.94      0.84      0.89        19
#                Coughing or sneezing       0.50      1.00      0.67         4
#                      Wiping a table       1.00      0.83      0.91         6
#                      Reading a book       0.90      1.00      0.95         9
#                  Neck roll exercise       1.00      1.00      1.00         5
#                   Freehand exercise       1.00      1.00      1.00         4
#                          Lying down       0.75      1.00      0.86        12
#                             Limping       1.00      0.50      0.67         2
#                Talking on the phone       0.89      0.62      0.73        13
#                    Using a computer       0.87      0.87      0.87        15
#                        Falling down       1.00      0.75      0.86         4
#                      Brushing teeth       1.00      1.00      1.00        15
#                             Writing       0.91      0.91      0.91        11
#                    Unknown activity       0.00      0.00      0.00         2
#
#                            accuracy                           0.89       159
#                           macro avg       0.85      0.86      0.84       159
#                        weighted avg       0.90      0.89      0.89       159
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay,ConfusionMatrixDisplay
cm = confusion_matrix(df['label'], df['predicted'])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=names)
disp.plot(xticks_rotation='vertical')

# %%
from os import listdir
from os.path import isfile, join
validation_path = "test_set"
onlyfiles = [f for f in listdir(validation_path) if isfile(join(validation_path, f))]

# %%
onlyfiles
# Out:
# ['video0029.mp4',
#  'video0023.mp4',
#  'video0054.mp4',
#  'video0050.mp4',
#  'video0179.mp4',
#  'video0209.mp4',
#  'video0038.mp4',
#  'video0169.mp4',
#  'video0141.mp4',
#  'video0233.mp4',
#  'video0154.mp4',
#  'video0090.mp4',
#  'video0092.mp4',
#  'video0063.mp4',
#  'video0110.mp4',
#  'video0022.mp4',
#  'video0188.mp4',
#  'video0117.mp4',
#  'video0077.mp4',
#  'video0087.mp4',
#  'video0032.mp4',
#  'video0145.mp4',
#  'video0088.mp4',
#  'video0098.mp4',
#  'video0198.mp4',
#  'video0005.mp4',
#  'video0189.mp4',
#  'video0210.mp4',
#  'video0224.mp4',
#  'video0159.mp4',
#  'video0046.mp4',
#  'video0089.mp4',
#  'video0195.mp4',
#  'video0231.mp4',
#  'video0218.mp4',
#  'video0144.mp4',
#  'video0119.mp4',
#  'video0105.mp4',
#  'video0151.mp4',
#  'video0150.mp4',
#  'video0086.mp4',
#  'video0148.mp4',
#  'video0125.mp4',
#  'video0237.mp4',
#  'video0216.mp4',
#  'video0001.mp4',
#  'video0134.mp4',
#  'video0011.mp4',
#  'video0017.mp4',
#  'video0109.mp4',
#  'video0043.mp4',
#  'video0149.mp4',
#  'video0031.mp4',
#  'video0018.mp4',
#  'video0239.mp4',
#  'video0168.mp4',
#  'video0115.mp4',
#  'video0245.mp4',
#  'video0121.mp4',
#  'video0006.mp4',
#  'video0083.mp4',
#  'video0009.mp4',
#  'video0111.mp4',
#  'video0003.mp4',
#  'video0202.mp4',
#  'video0177.mp4',
#  'video0107.mp4',
#  'video0213.mp4',
#  'video0118.mp4',
#  'video0024.mp4',
#  'video0030.mp4',
#  'video0173.mp4',
#  'video0019.mp4',
#  'video0249.mp4',
#  'video0008.mp4',
#  'video0065.mp4',
#  'video0200.mp4',
#  'video0164.mp4',
#  'video0037.mp4',
#  'video0058.mp4',
#  'video0126.mp4',
#  'video0175.mp4',
#  'video0163.mp4',
#  'video0114.mp4',
#  'video0240.mp4',
#  'video0162.mp4',
#  'video0062.mp4',
#  'video0170.mp4',
#  'video0156.mp4',
#  'video0000.mp4',
#  'video0066.mp4',
#  'video0093.mp4',
#  'video0044.mp4',
#  'video0215.mp4',
#  'video0079.mp4',
#  'video0039.mp4',
#  'video0113.mp4',
#  'video0247.mp4',
#  'video0016.mp4',
#  'video0020.mp4',
#  'video0219.mp4',
#  'video0203.mp4',
#  'video0128.mp4',
#  'video0230.mp4',
#  'video0069.mp4',
#  'video0160.mp4',
#  'video0232.mp4',
#  'video0080.mp4',
#  'video0204.mp4',
#  'video0047.mp4',
#  'video0186.mp4',
#  'video0045.mp4',
#  'video0197.mp4',
#  'video0034.mp4',
#  'video0212.mp4',
#  'video0201.mp4',
#  'video0180.mp4',
#  'video0059.mp4',
#  'video0120.mp4',
#  'video0130.mp4',
#  'video0060.mp4',
#  'video0085.mp4',
#  'video0102.mp4',
#  'video0028.mp4',
#  'video0132.mp4',
#  'video0099.mp4',
#  'video0191.mp4',
#  'video0176.mp4',
#  'video0007.mp4',
#  'video0167.mp4',
#  'video0127.mp4',
#  'video0187.mp4',
#  'video0161.mp4',
#  'video0040.mp4',
#  'video0138.mp4',
#  'video0035.mp4',
#  'video0053.mp4',
#  'video0075.mp4',
#  'video0221.mp4',
#  'video0027.mp4',
#  'video0076.mp4',
#  'video0112.mp4',
#  'video0012.mp4',
#  'video0205.mp4',
#  'video0081.mp4',
#  'video0241.mp4',
#  'video0143.mp4',
#  'video0068.mp4',
#  'video0036.mp4',
#  'video0025.mp4',
#  'video0190.mp4',
#  'video0071.mp4',
#  'video0135.mp4',
#  'video0222.mp4',
#  'video0136.mp4',
#  'video0026.mp4',
#  'video0211.mp4',
#  'video0082.mp4',
#  'video0055.mp4',
#  'video0182.mp4',
#  'video0184.mp4',
#  'video0052.mp4',
#  'video0228.mp4',
#  'video0033.mp4',
#  'video0183.mp4',
#  'video0129.mp4',
#  'video0051.mp4',
#  'video0157.mp4',
#  'video0048.mp4',
#  'video0181.mp4',
#  'video0155.mp4',
#  'video0133.mp4',
#  'video0049.mp4',
#  'video0021.mp4',
#  'video0091.mp4',
#  'video0116.mp4',
#  'video0139.mp4',
#  'video0172.mp4',
#  'video0225.mp4',
#  'video0199.mp4',
#  'video0056.mp4',
#  'video0152.mp4',
#  'video0246.mp4',
#  'video0101.mp4',
#  'video0207.mp4',
#  'video0103.mp4',
#  'video0010.mp4',
#  'video0073.mp4',
#  'video0067.mp4',
#  'video0214.mp4',
#  'video0146.mp4',
#  'video0014.mp4',
#  'video0131.mp4',
#  'video0235.mp4',
#  'video0074.mp4',
#  'video0196.mp4',
#  'video0072.mp4',
#  'video0070.mp4',
#  'video0229.mp4',
#  'video0178.mp4',
#  'video0042.mp4',
#  'video0064.mp4',
#  'video0004.mp4',
#  'video0100.mp4',
#  'video0238.mp4',
#  'video0227.mp4',
#  'video0041.mp4',
#  'video0217.mp4',
#  'video0094.mp4',
#  'video0248.mp4',
#  'video0123.mp4',
#  'video0171.mp4',
#  'video0095.mp4',
#  'video0244.mp4',
#  'video0206.mp4',
#  'video0243.mp4',
#  'video0147.mp4',
#  'video0097.mp4',
#  'video0193.mp4',
#  'video0140.mp4',
#  'video0015.mp4',
#  'video0165.mp4',
#  'video0057.mp4',
#  'video0124.mp4',
#  'video0166.mp4',
#  'video0220.mp4',
#  'video0137.mp4',
#  'video0078.mp4',
#  'video0084.mp4',
#  'video0096.mp4',
#  'video0223.mp4',
#  'video0226.mp4',
#  'video0104.mp4',
#  'video0194.mp4',
#  'video0142.mp4',
#  'video0236.mp4',
#  'video0158.mp4',
#  'video0208.mp4',
#  'video0192.mp4',
#  'video0106.mp4',
#  'video0122.mp4',
#  'video0002.mp4',
#  'video0242.mp4',
#  'video0108.mp4',
#  'video0153.mp4',
#  'video0234.mp4',
#  'video0174.mp4',
#  'video0185.mp4',
#  'video0061.mp4',
#  'video0013.mp4']

# %%
# model.load_state_dict(torch.load('videomae-icsr-heart/checkpoint-5000/pytorch_model.bin'))

# %%
# eval_results = {}
# for video in onlyfiles:
#     videoreader = VideoReader(validation_path + "/" + video, num_threads=1, ctx=cpu(0))
#     videoreader.seek(0)
#     indices = np.linspace(0, len(videoreader), num=128)
#     indices = np.clip(indices, 0, len(videoreader)- 1).astype(np.int64)
#     inputs = []
#     inputs.append(feature_extractor(list(videoreader.get_batch(indices).asnumpy()), return_tensors="pt")['pixel_values'][0])
#     inputs = torch.stack(inputs)
# #     print(inputs)
#     output = model(inputs.to(device='cuda'))
# #     print(names[torch.argmax(output['logits']).item()])
#     eval_results[video] = torch.argmax(output['logits']).item()
# eval_results

# %%
eval_results = {}
eval_labels = {}
eval_estimations = {}
for video in tqdm(onlyfiles):
    eval_estimations[video] = []
    videoreader = VideoReader(validation_path + "/" + video, num_threads=1, ctx=cpu(0))
    videoreader.seek(0)
    file_size = len(videoreader)
    batches = int(file_size/16)
    input_list = []
    for i in range(batches):
        indices = np.linspace(i, len(videoreader)-batches+i, num=16)
        indices = np.clip(indices, 0, len(videoreader)- 1).astype(np.int64)
        inputs = []
        inputs.append(feature_extractor(list(videoreader.get_batch(indices).asnumpy()), return_tensors="pt")['pixel_values'][0])
        input_list.append(torch.stack(inputs))
#     print(len(input_list))
    results = []
    for frame_seq in input_list:
        output = model(frame_seq.to(device='cuda'))
        eval_estimations[video].append(output['logits'])
        output = torch.argmax(output['logits']).item()
        results.append(output)
#     print(np.bincount(results).argmax())
    eval_results[video] = [np.bincount(results).argmax()]
    eval_labels[video] = results
#     print(names[torch.argmax(output['logits']).item()])
    
eval_results
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# DECORDError                               Traceback (most recent call last)
# Cell In [49], line 6
#       4 for video in tqdm(onlyfiles):
#       5     eval_estimations[video] = []
# ----> 6     videoreader = VideoReader(validation_path + "/" + video, num_threads=1, ctx=cpu(0))
#       7     videoreader.seek(0)
#       8     file_size = len(videoreader)
#
# File ~/.local/lib/python3.8/site-packages/decord/video_reader.py:54, in VideoReader.__init__(self, uri, ctx, width, height, num_threads, fault_tol)
#      51     self._handle = _CAPI_VideoReaderGetVideoReader(
#      52         ba, ctx.device_type, ctx.device_id, width, height, num_threads, 2, fault_tol)
#      53 else:
# ---> 54     self._handle = _CAPI_VideoReaderGetVideoReader(
#      55         uri, ctx.device_type, ctx.device_id, width, height, num_threads, 0, fault_tol)
#      56 if self._handle is None:
#      57     raise RuntimeError("Error reading " + uri + "...")
#
# File ~/.local/lib/python3.8/site-packages/decord/_ffi/_ctypes/function.py:173, in FunctionBase.__call__(self, *args)
#     171 ret_val = DECORDValue()
#     172 ret_tcode = ctypes.c_int()
# --> 173 check_call(_LIB.DECORDFuncCall(
#     174     self.handle, values, tcodes, ctypes.c_int(num_args),
#     175     ctypes.byref(ret_val), ctypes.byref(ret_tcode)))
#     176 _ = temp_args
#     177 _ = args
#
# File ~/.local/lib/python3.8/site-packages/decord/_ffi/base.py:78, in check_call(ret)
#      76         err_str = err_str.split('Stack trace')[0].strip()
#      77     raise DECORDLimitReachedError(err_str)
# ---> 78 raise DECORDError(err_str)
#
# DECORDError: [11:27:42] /github/workspace/src/video/video_reader.cc:151: Check failed: st_nb >= 0 (-1381258232 vs. 0) ERROR cannot find video stream with wanted index: -1

# %%
for x in dict(sorted(eval_results.items(), key=lambda item: item)).keys():
    if eval_results[x] != validation_labels[x][0]:
        print(f'{x}, predicted {names[eval_results[x]]} vs real {names[validation_labels[x][0]]}, {eval_results[x]} vs {validation_labels[x][0]}, Posible cases: {eval_labels[x]}')
# Out:
# video0000.mp4, predicted Writing vs real Wiping a table, 18 vs 8, Posible cases: [8, 18, 8, 18, 8, 18, 18, 18, 18]
# video0003.mp4, predicted Freehand exercise vs real Coughing or sneezing, 11 vs 7, Posible cases: [1, 1, 1, 1, 11, 11, 11, 11, 11]
# video0009.mp4, predicted Touching a hot surface vs real Unknown activity, 2 vs 19, Posible cases: [2, 2, 2, 2, 2, 2, 2, 2, 2]
# video0011.mp4, predicted Brushing teeth vs real Freehand exercise, 17 vs 11, Posible cases: [17, 17, 17, 17, 17, 17, 17, 17, 17]
# video0014.mp4, predicted Eating food with a fork vs real Talking on the phone, 6 vs 14, Posible cases: [6, 6, 6, 6, 6, 6, 6, 6, 6]
# video0015.mp4, predicted Limping vs real Colliding against something, 13 vs 5, Posible cases: [13, 13, 13, 13, 13, 13, 13, 13, 13]
# video0019.mp4, predicted Lying down vs real Falling down, 12 vs 16, Posible cases: [12, 12, 12, 12, 12, 12, 12, 12, 12]
# video0022.mp4, predicted Opening the door and walking in/out vs real Colliding against something, 0 vs 5, Posible cases: [0, 0, 0, 0, 0, 0, 16, 16, 0]
# video0025.mp4, predicted Falling down vs real Colliding against something, 16 vs 5, Posible cases: [16, 16, 16, 16, 16, 16, 16, 16, 16]
# video0026.mp4, predicted Coughing or sneezing vs real Eating food with a fork, 7 vs 6, Posible cases: [7, 7, 15, 15, 7, 7, 7, 7, 7, 15]
# video0027.mp4, predicted Using a computer vs real Writing, 15 vs 18, Posible cases: [15, 15, 15, 15, 15, 15, 15, 15]
# video0030.mp4, predicted Brushing teeth vs real Talking on the phone, 17 vs 14, Posible cases: [17, 17, 17, 17, 17, 17, 17, 17, 17]
# video0031.mp4, predicted Coughing or sneezing vs real Limping, 7 vs 13, Posible cases: [7, 7, 7, 7, 7, 12, 12, 12, 12]
# video0034.mp4, predicted Lying down vs real Colliding against something, 12 vs 5, Posible cases: [16, 12, 12, 12, 12, 12, 12, 12, 12]
# video0035.mp4, predicted Talking on the phone vs real Reading a book, 14 vs 9, Posible cases: [15, 14, 14, 14, 14, 14, 14, 14, 14, 15, 14, 14, 14]
# video0041.mp4, predicted Writing vs real Wiping a table, 18 vs 8, Posible cases: [18, 18, 17, 18, 18, 18, 17, 17, 17]
# video0043.mp4, predicted Putting on a jacket vs real Freehand exercise, 1 vs 11, Posible cases: [1, 1, 1, 1, 1, 1, 1, 1, 1]
# video0044.mp4, predicted Brushing teeth vs real Neck roll exercise, 17 vs 10, Posible cases: [17, 17, 17, 17, 17, 17, 17, 17, 17]
# video0046.mp4, predicted Limping vs real Coughing or sneezing, 13 vs 7, Posible cases: [13, 13, 13, 13, 4, 4, 4, 4, 13]
# video0048.mp4, predicted Talking on the phone vs real Reading a book, 14 vs 9, Posible cases: [14, 14, 14, 14, 14, 14, 14, 14, 14]
# video0050.mp4, predicted Writing vs real Coughing or sneezing, 18 vs 7, Posible cases: [18, 18, 18, 18, 18, 18, 12, 17, 17]
# video0053.mp4, predicted Limping vs real Using a computer, 13 vs 15, Posible cases: [13, 9, 15, 15, 13, 13, 13, 9, 13, 13]
# video0057.mp4, predicted Lying down vs real Talking on the phone, 12 vs 14, Posible cases: [12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12]
# video0059.mp4, predicted Brushing teeth vs real Freehand exercise, 17 vs 11, Posible cases: [17, 17, 17, 17, 17, 17, 17, 17, 17]
# video0060.mp4, predicted Drinking water vs real Freehand exercise, 4 vs 11, Posible cases: [4, 4, 4, 4, 4, 4, 4, 4, 4]
# video0066.mp4, predicted Opening the fridge vs real Touching a hot surface, 3 vs 2, Posible cases: [3, 3, 3, 3, 3, 3, 3, 3, 3]
# video0075.mp4, predicted Touching a hot surface vs real Unknown activity, 2 vs 19, Posible cases: [2, 2, 2, 2, 2, 2, 2]
# video0079.mp4, predicted Brushing teeth vs real Neck roll exercise, 17 vs 10, Posible cases: [17, 17, 17, 17, 10, 17, 17, 17, 17]
# video0082.mp4, predicted Putting on a jacket vs real Coughing or sneezing, 1 vs 7, Posible cases: [1, 1, 1, 1, 1, 1, 1, 1, 1]
# video0088.mp4, predicted Eating food with a fork vs real Wiping a table, 6 vs 8, Posible cases: [6, 6, 6, 6, 6, 6, 6, 6, 6]
# video0089.mp4, predicted Touching a hot surface vs real Wiping a table, 2 vs 8, Posible cases: [2, 2, 2, 2, 2, 2, 2, 2, 2]
# video0091.mp4, predicted Falling down vs real Coughing or sneezing, 16 vs 7, Posible cases: [16, 16, 16, 16, 16, 16, 16, 16, 16]
# video0093.mp4, predicted Opening the fridge vs real Touching a hot surface, 3 vs 2, Posible cases: [3, 3, 3, 3, 3, 3, 3, 3, 3]
# video0094.mp4, predicted Lying down vs real Limping, 12 vs 13, Posible cases: [12, 12, 12, 12, 12, 12, 12, 17, 12]
# video0096.mp4, predicted Limping vs real Colliding against something, 13 vs 5, Posible cases: [13, 13, 13, 13, 13, 13, 16, 16, 13]
# video0097.mp4, predicted Limping vs real Colliding against something, 13 vs 5, Posible cases: [13, 13, 13, 13, 13, 13, 13, 13, 13]
# video0102.mp4, predicted Eating food with a fork vs real Drinking water, 6 vs 4, Posible cases: [6, 6, 6, 6, 6, 6, 6, 6]
# video0107.mp4, predicted Limping vs real Unknown activity, 13 vs 19, Posible cases: [13, 13, 13, 13, 13, 13, 13]
# video0109.mp4, predicted Limping vs real Colliding against something, 13 vs 5, Posible cases: [13, 13, 13, 13, 13, 13, 13, 13, 13]
# video0110.mp4, predicted Coughing or sneezing vs real Eating food with a fork, 7 vs 6, Posible cases: [7, 7, 7, 7, 7, 7, 7, 7, 7, 7]
# video0112.mp4, predicted Eating food with a fork vs real Lying down, 6 vs 12, Posible cases: [16, 16, 12, 12, 12, 6, 6, 6, 6]
# video0114.mp4, predicted Drinking water vs real Freehand exercise, 4 vs 11, Posible cases: [4, 4, 4, 4, 4, 4, 4, 4, 4]
# video0117.mp4, predicted Brushing teeth vs real Freehand exercise, 17 vs 11, Posible cases: [17, 17, 17, 17, 17, 17, 17, 17, 17]
# video0118.mp4, predicted Lying down vs real Talking on the phone, 12 vs 14, Posible cases: [12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12]
# video0119.mp4, predicted Eating food with a fork vs real Talking on the phone, 6 vs 14, Posible cases: [6, 6, 6, 6, 6, 6, 14, 6, 6]
# video0121.mp4, predicted Opening the fridge vs real Touching a hot surface, 3 vs 2, Posible cases: [3, 3, 3, 3, 3, 3, 3, 3, 3]
# video0125.mp4, predicted Colliding against something vs real Unknown activity, 5 vs 19, Posible cases: [5, 5, 5, 1, 1, 5, 5]
# video0129.mp4, predicted Opening the door and walking in/out vs real Limping, 0 vs 13, Posible cases: [0, 0, 0, 0, 0, 0, 0, 0, 0]
# video0131.mp4, predicted Drinking water vs real Neck roll exercise, 4 vs 10, Posible cases: [4, 4, 4, 4, 4, 4, 4, 13, 13]
# video0135.mp4, predicted Lying down vs real Limping, 12 vs 13, Posible cases: [12, 12, 12, 12, 12, 12, 12, 12, 12]

# %%
torch.stack(eval_estimations['video0000.mp4'], dim=0).sum(dim=0)
# for result in range(len(eval_estimations['video0000.mp4'])):
#     print(eval_estimations['video0000.mp4'][result] ,eval_labels['video0000.mp4'][result])
# Out:
# tensor([[ -7.1302, -15.0484, -12.1665,  -9.0507,  -1.7132,  -7.9959,   4.8482,
#           -6.6244,  10.4697,  -7.1200,  -3.9928,  -7.8140,  -0.8858,  -8.7205,
#            4.7883,   7.2673,  -8.6436,  -4.5161,  10.7741, -11.0969]],
#        device='cuda:0', grad_fn=<SumBackward1>)

# %%
for x in eval_results.keys():
    eval_results[x] = "[" + str(eval_results[x]) + "]"

# %%
eval_results
# Out:
# {'video0029.mp4': '[9]',
#  'video0023.mp4': '[15]',
#  'video0054.mp4': '[17]',
#  'video0050.mp4': '[11]',
#  'video0038.mp4': '[18]',
#  'video0090.mp4': '[2]',
#  'video0092.mp4': '[16]',
#  'video0063.mp4': '[3]',
#  'video0110.mp4': '[7]',
#  'video0022.mp4': '[5]',
#  'video0117.mp4': '[7]',
#  'video0077.mp4': '[6]',
#  'video0087.mp4': '[3]',
#  'video0032.mp4': '[0]',
#  'video0088.mp4': '[6]',
#  'video0098.mp4': '[4]',
#  'video0005.mp4': '[16]',
#  'video0046.mp4': '[5]',
#  'video0089.mp4': '[19]',
#  'video0119.mp4': '[14]',
#  'video0105.mp4': '[16]',
#  'video0086.mp4': '[17]',
#  'video0125.mp4': '[1]',
#  'video0001.mp4': '[18]',
#  'video0134.mp4': '[9]',
#  'video0011.mp4': '[19]',
#  'video0017.mp4': '[8]',
#  'video0109.mp4': '[5]',
#  'video0043.mp4': '[7]',
#  'video0031.mp4': '[7]',
#  'video0018.mp4': '[15]',
#  'video0115.mp4': '[1]',
#  'video0121.mp4': '[3]',
#  'video0006.mp4': '[4]',
#  'video0083.mp4': '[0]',
#  'video0009.mp4': '[2]',
#  'video0111.mp4': '[10]',
#  'video0003.mp4': '[11]',
#  'video0107.mp4': '[0]',
#  'video0118.mp4': '[12]',
#  'video0024.mp4': '[3]',
#  'video0030.mp4': '[14]',
#  'video0019.mp4': '[16]',
#  'video0008.mp4': '[1]',
#  'video0065.mp4': '[17]',
#  'video0037.mp4': '[1]',
#  'video0058.mp4': '[17]',
#  'video0126.mp4': '[4]',
#  'video0114.mp4': '[4]',
#  'video0062.mp4': '[6]',
#  'video0000.mp4': '[8]',
#  'video0066.mp4': '[3]',
#  'video0093.mp4': '[3]',
#  'video0044.mp4': '[10]',
#  'video0079.mp4': '[10]',
#  'video0039.mp4': '[9]',
#  'video0113.mp4': '[17]',
#  'video0016.mp4': '[3]',
#  'video0020.mp4': '[15]',
#  'video0128.mp4': '[6]',
#  'video0069.mp4': '[3]',
#  'video0080.mp4': '[4]',
#  'video0047.mp4': '[10]',
#  'video0045.mp4': '[2]',
#  'video0034.mp4': '[5]',
#  'video0059.mp4': '[19]',
#  'video0120.mp4': '[7]',
#  'video0130.mp4': '[0]',
#  'video0060.mp4': '[4]',
#  'video0085.mp4': '[3]',
#  'video0102.mp4': '[4]',
#  'video0028.mp4': '[16]',
#  'video0132.mp4': '[14]',
#  'video0099.mp4': '[18]',
#  'video0007.mp4': '[15]',
#  'video0127.mp4': '[4]',
#  'video0040.mp4': '[6]',
#  'video0035.mp4': '[6]',
#  'video0053.mp4': '[15]',
#  'video0075.mp4': '[2]',
#  'video0027.mp4': '[15]',
#  'video0076.mp4': '[4]',
#  'video0112.mp4': '[16]',
#  'video0012.mp4': '[4]',
#  'video0081.mp4': '[16]',
#  'video0068.mp4': '[18]',
#  'video0036.mp4': '[12]',
#  'video0025.mp4': '[16]',
#  'video0071.mp4': '[12]',
#  'video0135.mp4': '[7]',
#  'video0026.mp4': '[6]',
#  'video0082.mp4': '[7]',
#  'video0055.mp4': '[4]',
#  'video0052.mp4': '[13]',
#  'video0033.mp4': '[6]',
#  'video0129.mp4': '[0]',
#  'video0051.mp4': '[5]',
#  'video0048.mp4': '[10]',
#  'video0133.mp4': '[2]',
#  'video0049.mp4': '[4]',
#  'video0021.mp4': '[1]',
#  'video0091.mp4': '[16]',
#  'video0116.mp4': '[8]',
#  'video0056.mp4': '[14]',
#  'video0101.mp4': '[1]',
#  'video0103.mp4': '[10]',
#  'video0010.mp4': '[14]',
#  'video0073.mp4': '[15]',
#  'video0067.mp4': '[15]',
#  'video0014.mp4': '[6]',
#  'video0131.mp4': '[4]',
#  'video0074.mp4': '[17]',
#  'video0072.mp4': '[17]',
#  'video0070.mp4': '[13]',
#  'video0042.mp4': '[11]',
#  'video0064.mp4': '[18]',
#  'video0004.mp4': '[18]',
#  'video0100.mp4': '[4]',
#  'video0041.mp4': '[6]',
#  'video0094.mp4': '[13]',
#  'video0123.mp4': '[17]',
#  'video0095.mp4': '[16]',
#  'video0097.mp4': '[5]',
#  'video0015.mp4': '[13]',
#  'video0057.mp4': '[12]',
#  'video0124.mp4': '[0]',
#  'video0078.mp4': '[9]',
#  'video0084.mp4': '[0]',
#  'video0096.mp4': '[5]',
#  'video0104.mp4': '[9]',
#  'video0106.mp4': '[15]',
#  'video0122.mp4': '[18]',
#  'video0002.mp4': '[10]',
#  'video0108.mp4': '[6]',
#  'video0061.mp4': '[9]',
#  'video0013.mp4': '[0]'}
